# %%
import torch

input_path = '/opt/data/269-single-timestep-EXP-1-head/374/sequences/EXP-1-head/timesteps/frame_00000/input_dictionary.npz'

input_dict = torch.load(input_path)
images = input_dict['images']

import matplotlib.pyplot as plt
import numpy as np

# Plot the 2D image
plt.imshow(list(images.values())[4].permute(1,2,0), cmap='viridis')  # You can choose different colormaps, e.g., 'gray', 'viridis', etc.
plt.colorbar()  # Show color scale
plt.title('2D Image')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()
